# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from pandas import DataFrame , read_csv
#for f in os.listdir('../input/'):
#    print (f.ljust(30)+ str(round(os.path.getsize('../input/'+f)/10000, 2)) + 'MB')


# df.head()

# Plotting a bar graph of the number of stores in each city, for the first ten cities listed
# in the column 'City'
"""
city_count  = df['City'].value_counts()
city_count = city_count[:10,]
plt.figure(figsize=(10,5))
sns.barplot(city_count.index, city_count.values, alpha=0.8)
plt.title('Starbucks in top 10 cities in the World')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('city', fontsize=12)
plt.show()
"""
baloncesto = pd.read_csv('/home/daniel/baloncesto.csv', index_col='X')


df = pd.DataFrame(baloncesto)
df
# Out:
#        Nombre              Equipo  Edad  Estatura  Salario   Posición  \
# X
# 0    Giedrius                 NBA    22      2.13  30.000€       Base
# 1   Mindaugas       Brooklyn_Nets    27      2.05  34.000€    Escolta
# 2     Arvydas      Boston_Celtics    25      2.17  36.000€      Alero
# 3     Saulius  Los_Angeles_Lakers    30      2.15  32.000€       Base
# 4     Ramunas                 NBA    29      2.09  30.000€  Ala-Pivot
# 5      Darius      Boston_Celtics    33      2.05  35.000€      Alero
# 6     Donatas  Los_Angeles_Lakers    25      2.10  32.000€      Pivot
# 7     Ksistof      Boston_Celtics    28      2.11  36.000€       Base
# 8         Pau                 NBA    30      2.16  40.000€      Alero
# 9       Roger     Valencia_Basket    24      2.09  36.000€      Pivot
# 10      Jorge             Unicaja    31      2.10  31.000€    Escolta
# 11     Carlos     Valencia_Basket    22      2.14  33.000€       Base
#
#     Rebotes  Robos  Triples  Asistencias  Puntos
# X
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame , read_csv

baloncesto = pd.read_csv('/home/daniel/baloncesto.csv', index_col='X')
df = pd.DataFrame(baloncesto)

point_count  = df['Nombre'].value_counts()
point_count = city_count[:12,]
plt.figure(figsize=(10,5))
sns.barplot(point_count.index, point_count.values, alpha=0.8)
plt.title('Estadísticas jugadores')
plt.ylabel('Puntos', fontsize=12)
plt.xlabel('Jugador', fontsize=12)
plt.show()
