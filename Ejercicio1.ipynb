# %%
from faker import Faker
import pandas as pd
import array as arr
from random import randrange

fake = Faker()

fake.name()
# 'Lucy Cechtelar'

fake.address()
# "426 Jordy Lodge
#  Cartwrightshire, SC 88120-6700"

fake.text(1000)
# Sint velit eveniet. Rerum atque repellat voluptatem quia rerum. Numquam excepturi
# beatae sint laudantium consequatur. Magni occaecati itaque sint et sit tempore. Nesciunt
# amet quidem. Iusto deleniti cum autem ad quia aperiam.
# A consectetur quos aliquam. In iste aliquid et aut similique suscipit. Consequatur qui
# quaerat iste minus hic expedita. Consequuntur error magni et laboriosam. Aut aspernatur
# voluptatem sit aliquam. Dolores voluptatum est.
# Aut molestias et maxime. Fugit autem facilis quos vero. Eius quibusdam possimus est.
# Ea quaerat et quisquam. Deleniti sunt quam. Adipisci consequatur id in occaecati.
# Et sint et. Ut ducimus quod nemo ab voluptatum.

nombre = fake.name()
direccion = fake.address()
telefono = fake.random_number(9)
mail = fake.email(20)

usuario = [nombre, direccion, telefono, mail]
print(usuario)

aleatorio = randrange(50)

i = 1

while i <= aleatorio:
    nombre = fake.name()
    direccion = fake.address()
    telefono = fake.random_number(9)
    mail = fake.email(20)
    usuario = [nombre, direccion, telefono, mail]
    
    print(i)
    print(usuario)
    
    #fila[i] = {'nombre': nombre, 'direccion': direccion, 'telefono': telefono, 'email': mail}
    i += 1
print("Programa terminado")


#array = {'nombre': fake.name(), 'direccion': fake.address(), 'telefono': fake.random_number(9), 'email': fake.email(20)}
#fila[i] = {'nombre': nombre, 'direccion': direccion, 'telefono': telefono, 'email': mail}
#fila2 = {'nombre': nombre, 'direccion': direccion, 'telefono': telefono, 'email': mail}
#fila3 = {'nombre': nombre, 'direccion': direccion, 'telefono': telefono, 'email': mail}
#print(arr)


#miarray = [fila[1], fila[2], fila[3], fila[4], fila[5], fila[6], fila[7], fila[8], fila[9], fila[10], fila[11], fila[12], fila[13], fila[14], fila[15], fila[16], fila[17], fila[18], fila[19], fila[20], fila[21], fila[22], fila[23], fila[24], fila[25], fila[26], fila[27], fila[28], fila[29], fila[30], fila[31], fila[32], fila[33], fila[34], fila[35], fila[36], fila[37], fila[38], fila[39], fila[40]]
#miarray = [fila[1], fila[2], fila[3], fila[4], fila[5], fila[6], fila[7], fila[8], fila[9], fila[10], fila[11], fila[12], fila[13], fila[14], fila[15], fila[16], fila[17], fila[18], fila[19], fila[20], fila[21], fila[22], fila[23], fila[24], fila[25], fila[26], fila[27], fila[28], fila[29], fila[30], fila[31], fila[32], fila[33], fila[34], fila[35], fila[36], fila[37], fila[38], fila[39], fila[40]]
#miarray = [fila[1], fila[2], fila[3], fila[4]]
#d = [{'nombre': [nombre], 'direccion': [direccion], 'telefono': [telefono], 'email': [mail]},
#    {'nombre': [nombre], 'direccion': [direccion], 'telefono': [telefono], 'email': [mail]}]

#df = pd.DataFrame(miarray)
#df

#df = pd.DataFrame(data)
#df


#while i <= 50:
#    fila[i] = None
#    i += 1

#import pandas as pd
#inp = [{'c1':10, 'c2':100}, {'c1':11,'c2':110}, {'c1':12,'c2':120}]
#df = pd.DataFrame(inp)
#print df
# Out:
# ['Malik Simon', '867 Dorsey Turnpike Suite 191\nLake Kathy, OH 13399', 745117841, 'kmitchell@20']
# 1
# ['Heather Harris', '4818 James Terrace Apt. 812\nWest Ryan, WV 34902', 339204034, 'amy87@20']
# 2
# ['Robert Jones', '75811 Gomez Mews\nChadbury, ND 74046', 383616491, 'carly46@20']
# 3
# ['Robert Noble', '5243 Nelson Lodge\nPort Ronaldshire, ND 05298', 611413677, 'janet74@20']
# 4
# ['David Rocha', '2201 Kyle Via Suite 226\nEricport, KY 68693', 126743109, 'ramirezkeith@20']
# 5
# ['Jeffrey Rivera', '5127 Jenkins Plains\nSuzannebury, NV 90933', 609965420, 'pcruz@20']
# 6
# ['Willie Dennis', '142 Richard Pines Suite 979\nLaurahaven, OK 93221', 188826425, 'john33@20']
# 7
# ['Jessica Jarvis', '47166 Rebecca Canyon Suite 811\nNew Samantha, MD 12502', 247836200, 'murphymaria@20']
# 8
# ['Darren Johnson', 'Unit 8920 Box 2725\nDPO AA 80176', 72059906, 'carriegonzalez@20']
# 9
# ['Maria Payne', '538 Mitchell Station\nEast Robertberg, TX 38712', 546087839, 'vlozano@20']
# 10
# ...
