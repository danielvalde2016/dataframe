# %%
from faker import Faker
import pandas as pd
import array as arr
from random import randint

fake = Faker()

aleatorio = randint(25, 50)

cols = ['nombre', 'direccion', 'telefono', 'email']
df = pd.DataFrame(columns=cols, index=range(aleatorio))
for a in range(aleatorio):
    nombre = fake.name()
    direccion = fake.address()
    telefono = fake.random_number(9)
    mail = fake.email(20)

    df.loc[a].nombre = nombre
    df.loc[a].direccion = direccion
    df.loc[a].telefono = telefono
    df.loc[a].email = mail
df
# Out:
#                    nombre                                          direccion  \
# 0            Carlos Jones  23673 Newton Glens Apt. 253\nWhiteville, IN 57060
# 1           Michael Munoz  3371 Lara Gateway Suite 024\nNorth Richardside...
# 2              Fred Boone  561 Hailey Roads Suite 750\nPort Kylieville, V...
# 3           Robert Harris  0254 Shepard Ports Suite 574\nPort Jennifer, N...
# 4             Lisa Nguyen            83606 Jordan Tunnel\nReedstad, KS 82086
# 5             Mario Clark  31859 Smith Inlet Apt. 237\nDavenportland, TX ...
# 6           Angela Morrow     33437 Flores Fork\nPort Brittanytown, LA 68157
# 7               Jose Hill  53932 Tony Locks Suite 336\nEast Rodney, MI 59492
# 8              Maria King  78375 Jeremy Mill Suite 487\nNew Margaret, NH ...
# 9         Carrie Crawford                   PSC 1756, Box 7354\nAPO AE 71377
# 10   Mrs. Jordan Mcdonald  5419 Randy Drives Suite 649\nNew Justin, MS 38413
# 11       Elizabeth Oneill  9493 Christopher Forks Suite 744\nNew Williamc...
# 12         Gloria Johnson                625 Floyd Ports\nWisetown, GA 79842
# 13           Mandy Foster  035 Mcclain Cove Apt. 897\nNicholasmouth, ID 5...
# 14          Zachary Owens                   Unit 7421 Box 0561\nDPO AP 96629
# 15          Jeffrey Silva  379 Wright Hollow Suite 136\nWest Alexandriafo...
# 16        Maria Robertson             206 Ricardo Flats\nWardville, CA 22482
# 17       Alexandra Jacobs  521 Osborne Island Suite 742\nEast Jill, KS 49009
# 18       Jeffrey Richards   1540 Holland Wall Suite 177\nTracyport, PA 66889
# 19            Kelly Lucas  5301 Graham Cliff Suite 798\nLake Daniel, AK 4...
# 20         Jennifer Lopez        2724 Hughes Canyon\nNorth Richard, SC 38981
# 21          Nathan Harmon       047 Shelby Underpass\nLindsayshire, SC 53935
# 22           Shaun Monroe  150 Randy Heights Suite 268\nChristineside, AR...
# 23            Sheri White   2531 Kevin Courts Apt. 974\nHarrisfurt, WA 38144
# 24        Brendan Manning                           USCGC Khan\nFPO AE 10517
# 25         William Bryant  09353 James Port Suite 187\nWest Kyleborough, ...
# 26           Joan Wilkins  444 Dennis Island Apt. 437\nAmandashire, WI 23974
# 27           James Butler                   PSC 9772, Box 9658\nAPO AP 96446
# 28      Christopher Henry  29756 Ryan Cliff Suite 976\nPort Davidchester,...
# 29  Mrs. Rebekah Chambers          776 Brenda Ville\nDawsonborough, MI 75369
# 30            David Riley                   PSC 5342, Box 8523\nAPO AE 70972
# 31        Richard Shepard  5885 Sims Prairie Apt. 695\nNew Brianmouth, IN...
# 32      Stephanie Pacheco            8190 Beltran Estate\nDiazport, CO 78304
# 33       Dr. Debra Keller     3336 Dickerson Villages\nSouth James, TN 16194
# 34            Susan James  5489 Manuel Isle Suite 141\nNew Allenport, OR ...
# 35          Betty Fischer        406 Karen Pass Apt. 473\nRamoston, OH 22534
# 36        Dr. David Yates  5071 Ramirez Point Suite 601\nSouth Gregoryche...
# 37           Kaylee Mason  6794 David Stravenue Apt. 624\nNew Paul, AZ 27533
# 38           Jordan Allen       7609 Merritt Pass\nWest Deannaside, ND 05628
#
#      telefono                email
# 0   698895443    robinsonmartha@20
# 1   385089103      lewismatthew@20
# 2   952911825          sheena45@20
# 3   191306296         brownjuan@20
# 4   837471243          trevor23@20
# 5   609785313         ophillips@20
# 6   455145818           aspears@20
# 7   301139050  dominguezrebecca@20
# 8   243734796        coreyjones@20
# 9   200088842           jhudson@20
# 10  301443686           mwright@20
# 11  639845659          sgriffin@20
# 12  339885470            xscott@20
# 13  228713057            vbrown@20
# 14  998817517           bryce13@20
# 15  660088685           kharper@20
# 16   24072758          rachel80@20
# 17  143528572      herrerashawn@20
# 18  122721276           terri73@20
# 19  924901206            kara36@20
# 20  468668160         vincent39@20
# 21  297960968   cisnerosmichael@20
# 22  831357255           diane64@20
# 23  468429989            bnolan@20
# 24  584592168     kristapearson@20
# 25  131234709     crawfordcindy@20
# 26  157805249         bfranklin@20
# 27  685811465         dwilliams@20
# 28  401419456  nicholsondominic@20
# 29  314271823    figueroatravis@20
# 30  548432345            drusso@20
# 31  655078562     jameswilliams@20
# 32  918594406      angelamclean@20
# 33   33845756          olivia82@20
# 34  926556479           grivera@20
# 35  585572433        bryanwhite@20
# 36   70390045         melissa32@20
# 37  212780942       robertsmith@20
# 38  877175568       davidwatson@20
